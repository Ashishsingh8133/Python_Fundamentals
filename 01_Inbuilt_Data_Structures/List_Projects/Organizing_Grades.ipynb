# %%
#organizing student grades
grades=[76,78,81,84,87]

#adding new grades
grades.append(91)

#average marks calculation
average=sum(grades)/len(grades)
print(f" Average grades:{average:.2f}")

#find the highest and lowest grades
highest_grades=max(grades)
lowest_grades=min(grades)
print(f"Highest grades: {highest_grades:.2f}")
print(f"lowest grades :{lowest_grades:.2f}")
# Out:
#  Average grades:82.83
# Highest grades: 91.00
# lowest grades :76.00
