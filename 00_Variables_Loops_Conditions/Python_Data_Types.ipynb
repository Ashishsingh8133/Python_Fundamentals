# %% [markdown]
# # Python Data Types
#
# This notebook contains my practical work on **Python Data Types**. The original code is preserved, with Markdown sections added to make the concepts and examples clear for GitHub.

# %% [markdown]
# ## Numeric Data Types
#
# Working with Python integer and floating-point values.

# %%
#Integers 
#Floating Point NUmbers
#String
#Boolean
age=20;
print(age, type(age))
height=20.00
print(height,type(height))
is_student=True
print(is_student,type(is_student))
# Out:
# 20 <class 'int'>
# 20.0 <class 'float'>
# True <class 'bool'>

# %%
#boolean variables
name='ashish'
Name='Singh'
print(name==Name,type(name==Name))
# Out:
# False <class 'bool'>

# %%
##common errors
 
result = str('ashish') + str(5) #here u will get an error because u can add string to string 
#not string with integer value if u want to do it u have to perform type casting convert int into str

# %%
result='ashish' + str(5)
print(result)
# Out:
# ashish5

# %% [markdown]
# ## Key Takeaways
#
# - Practised the main **python data types** concepts demonstrated in this notebook.
# - Used practical Python examples to understand how the concepts work.
# - Original code cells have been preserved.
